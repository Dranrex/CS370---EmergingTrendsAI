# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.985074875, score: 23
# Scores: (min: 23, avg: 23, max: 23)
#
# Run: 2, exploration: 0.9000874278732445, score: 19
# Scores: (min: 19, avg: 21, max: 23)
#
# Run: 3, exploration: 0.8390886103705794, score: 15
# Scores: (min: 15, avg: 19, max: 23)
#
# Run: 4, exploration: 0.7822236754458713, score: 15
# Scores: (min: 15, avg: 18, max: 23)
#
# Run: 5, exploration: 0.697046600835495, score: 24
# Scores: (min: 15, avg: 19.2, max: 24)
#
# Run: 6, exploration: 0.6465587967553006, score: 16
# Scores: (min: 15, avg: 18.666666666666668, max: 24)
#
# Run: 7, exploration: 0.6149486215357263, score: 11
# Scores: (min: 11, avg: 17.571428571428573, max: 24)
#
# Run: 8, exploration: 0.4982051627146237, score: 43
# Scores: (min: 11, avg: 20.75, max: 43)
#
# Run: 9, exploration: 0.46211964903917074, score: 16
# Scores: (min: 11, avg: 20.22222222222222, max: 43)
#
# Run: 10, exploration: 0.42650460709830135, score: 17
# Scores: (min: 11, avg: 19.9, max: 43)
#
# Run: 11, exploration: 0.40565285250151817, score: 11
# Scores: (min: 11, avg: 19.09090909090909, max: 43)
#
# Run: 12, exploration: 0.37816180712868996, score: 15
# Scores: (min: 11, avg: 18.75, max: 43)
#
# Run: 13, exploration: 0.3472722151889232, score: 18
# Scores: (min: 11, avg: 18.692307692307693, max: 43)
#
# Run: 14, exploration: 0.30483872516307353, score: 27
# Scores: (min: 11, avg: 19.285714285714285, max: 43)
#
# Run: 15, exploration: 0.2799384215094006, score: 18
# Scores: (min: 11, avg: 19.2, max: 43)
#
# Run: 16, exploration: 0.25450776877280124, score: 20
# Scores: (min: 11, avg: 19.25, max: 43)
#
# Run: 17, exploration: 0.2211807388415433, score: 29
# Scores: (min: 11, avg: 19.823529411764707, max: 43)
#
# Run: 18, exploration: 0.17651675623376062, score: 46
# Scores: (min: 11, avg: 21.27777777777778, max: 46)
#
# Run: 19, exploration: 0.1451730787173275, score: 40
# Scores: (min: 11, avg: 22.263157894736842, max: 46)
#
# Run: 20, exploration: 0.10800599224428936, score: 60
# Scores: (min: 11, avg: 24.15, max: 60)
#
# Run: 21, exploration: 0.08075818212241151, score: 59
# Scores: (min: 11, avg: 25.80952380952381, max: 60)
#
# Run: 22, exploration: 0.05830244700006734, score: 66
# Scores: (min: 11, avg: 27.636363636363637, max: 66)
#
# Run: 23, exploration: 0.045605554379880814, score: 50
# Scores: (min: 11, avg: 28.608695652173914, max: 66)
#
# Run: 24, exploration: 0.027214167668287145, score: 104
# Scores: (min: 11, avg: 31.75, max: 104)
#
# Run: 25, exploration: 0.014912990653247866, score: 121
# Scores: (min: 11, avg: 35.32, max: 121)
#
# Run: 26, exploration: 0.010605575411209664, score: 69
# Scores: (min: 11, avg: 36.61538461538461, max: 121)
#
# Run: 27, exploration: 0.01, score: 106
# Scores: (min: 11, avg: 39.18518518518518, max: 121)
#
# Run: 28, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 42.357142857142854, max: 128)
#
# Run: 29, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 45.689655172413794, max: 139)
#
# Run: 30, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 48.5, max: 139)
#
# Run: 31, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 50.25806451612903, max: 139)
#
# Run: 32, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 52.96875, max: 139)
#
# Run: 33, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 56.03030303030303, max: 154)
#
# Run: 34, exploration: 0.01, score: 189
# Scores: (min: 11, avg: 59.94117647058823, max: 189)
#
# Run: 35, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 62.4, max: 189)
#
# Run: 36, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 64.75, max: 189)
#
# Run: 37, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 67.08108108108108, max: 189)
#
# Run: 38, exploration: 0.01, score: 172
# Scores: (min: 11, avg: 69.84210526315789, max: 189)
#
# Run: 39, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 72.17948717948718, max: 189)
#
# Run: 40, exploration: 0.01, score: 216
# Scores: (min: 11, avg: 75.775, max: 216)
#
# Run: 41, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 77.97560975609755, max: 216)
#
# Run: 42, exploration: 0.01, score: 185
# Scores: (min: 11, avg: 80.52380952380952, max: 216)
#
# Run: 43, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 83.23255813953489, max: 216)
#
# Run: 44, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 85, max: 216)
#
# Run: 45, exploration: 0.01, score: 178
# Scores: (min: 11, avg: 87.06666666666666, max: 216)
#
# Run: 46, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 88.95652173913044, max: 216)
#
# Run: 47, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 90.1063829787234, max: 216)
#
# Run: 48, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 91.58333333333333, max: 216)
#
# Run: 49, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 93.36734693877551, max: 216)
#
# Run: 50, exploration: 0.01, score: 172
# Scores: (min: 11, avg: 94.94, max: 216)
#
# Run: 51, exploration: 0.01, score: 186
# Scores: (min: 11, avg: 96.72549019607843, max: 216)
#
# Run: 52, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 97.92307692307692, max: 216)
#
# Run: 53, exploration: 0.01, score: 169
# Scores: (min: 11, avg: 99.26415094339623, max: 216)
#
# Run: 54, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 100.31481481481481, max: 216)
#
# Run: 55, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 101.49090909090908, max: 216)
#
# Run: 56, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 102.53571428571429, max: 216)
#
# Run: 57, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 103.45614035087719, max: 216)
#
# Run: 58, exploration: 0.01, score: 188
# Scores: (min: 11, avg: 104.91379310344827, max: 216)
#
# Run: 59, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 105.9322033898305, max: 216)
#
# Run: 60, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 106.61666666666666, max: 216)
#
# Run: 61, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 107.22950819672131, max: 216)
#
# Run: 62, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 108.75806451612904, max: 216)
#
# Run: 63, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 109.25396825396825, max: 216)
#
# Run: 64, exploration: 0.01, score: 232
# Scores: (min: 11, avg: 111.171875, max: 232)
#
# Run: 65, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 111.41538461538461, max: 232)
#
# Run: 66, exploration: 0.01, score: 180
# Scores: (min: 11, avg: 112.45454545454545, max: 232)
#
# Run: 67, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 112.98507462686567, max: 232)
#
# Run: 68, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 114.22058823529412, max: 232)
#
# Run: 69, exploration: 0.01, score: 358
# Scores: (min: 11, avg: 117.7536231884058, max: 358)
#
# Run: 70, exploration: 0.01, score: 181
# Scores: (min: 11, avg: 118.65714285714286, max: 358)
#
# Run: 71, exploration: 0.01, score: 250
# Scores: (min: 11, avg: 120.50704225352112, max: 358)
#
# Run: 72, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 120.38888888888889, max: 358)
#
# Run: 73, exploration: 0.01, score: 240
# Scores: (min: 11, avg: 122.02739726027397, max: 358)
#
# Run: 74, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 122.97297297297297, max: 358)
#
# Run: 75, exploration: 0.01, score: 134
# Scores: (min: 11, avg: 123.12, max: 358)
#
# Run: 76, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 123.46052631578948, max: 358)
#
# Run: 77, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 123.67532467532467, max: 358)
#
# Run: 78, exploration: 0.01, score: 195
# Scores: (min: 11, avg: 124.58974358974359, max: 358)
#
# Run: 79, exploration: 0.01, score: 267
# Scores: (min: 11, avg: 126.39240506329114, max: 358)
#
# Run: 80, exploration: 0.01, score: 134
# Scores: (min: 11, avg: 126.4875, max: 358)
#
# Run: 81, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 126.50617283950618, max: 358)
#
# Run: 82, exploration: 0.01, score: 96
# Scores: (min: 11, avg: 126.13414634146342, max: 358)
#
# Run: 83, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 124.74698795180723, max: 358)
#
# Run: 84, exploration: 0.01, score: 205
# Scores: (min: 11, avg: 125.70238095238095, max: 358)
#
# Run: 85, exploration: 0.01, score: 219
# Scores: (min: 11, avg: 126.8, max: 358)
#
# Run: 86, exploration: 0.01, score: 48
# Scores: (min: 11, avg: 125.88372093023256, max: 358)
#
# Run: 87, exploration: 0.01, score: 134
# Scores: (min: 11, avg: 125.97701149425288, max: 358)
#
# Run: 88, exploration: 0.01, score: 187
# Scores: (min: 11, avg: 126.67045454545455, max: 358)
#
# Run: 89, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 126.57303370786516, max: 358)
# Run: 90, exploration: 0.01, score: 339
# Scores: (min: 11, avg: 128.93333333333334, max: 358)
#
# Run: 91, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 129.04395604395606, max: 358)
#
# Run: 92, exploration: 0.01, score: 196
# Scores: (min: 11, avg: 129.77173913043478, max: 358)
#
# Run: 93, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 129.9784946236559, max: 358)
#
# Run: 94, exploration: 0.01, score: 195
# Scores: (min: 11, avg: 130.67021276595744, max: 358)
#
# Run: 95, exploration: 0.01, score: 211
# Scores: (min: 11, avg: 131.5157894736842, max: 358)
#
# Run: 96, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 132.19791666666666, max: 358)
#
# Run: 97, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 132.41237113402062, max: 358)
#
# Run: 98, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 132.41836734693877, max: 358)
#
# Run: 99, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 132.83838383838383, max: 358)
#
# Run: 100, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 132.79, max: 358)
#
# Run: 101, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 134.27, max: 358)
#
# Run: 102, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 135.31, max: 358)
#
# Run: 103, exploration: 0.01, score: 117
# Scores: (min: 11, avg: 136.33, max: 358)
#
# Run: 104, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 137.33, max: 358)
#
# Run: 105, exploration: 0.01, score: 148
# Scores: (min: 11, avg: 138.57, max: 358)
#
# Run: 106, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 139.69, max: 358)
#
# Run: 107, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 140.88, max: 358)
#
# Run: 108, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 141.69, max: 358)
#
# Run: 109, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 143.17, max: 358)
#
# Run: 110, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 144.76, max: 358)
#
# Run: 111, exploration: 0.01, score: 210
# Scores: (min: 11, avg: 146.75, max: 358)
#
# Run: 112, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 148.26, max: 358)
#
# Run: 113, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 149.4, max: 358)
#
# Run: 114, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 150.56, max: 358)
#
# Run: 115, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 151.97, max: 358)
#
# Run: 116, exploration: 0.01, score: 135
# Scores: (min: 11, avg: 153.12, max: 358)
#
# Run: 117, exploration: 0.01, score: 214
# Scores: (min: 11, avg: 154.97, max: 358)
#
# Run: 118, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 155.81, max: 358)
#
# Run: 119, exploration: 0.01, score: 288
# Scores: (min: 11, avg: 158.29, max: 358)
#
# Run: 120, exploration: 0.01, score: 254
# Scores: (min: 11, avg: 160.23, max: 358)
#
# Run: 121, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 160.92, max: 358)
#
# Run: 122, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 161.93, max: 358)
#
# Run: 123, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 162.67, max: 358)
#
# Run: 124, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 163.67, max: 358)
#
# Run: 125, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 163.92, max: 358)
#
# Run: 126, exploration: 0.01, score: 224
# Scores: (min: 11, avg: 165.47, max: 358)
#
# Run: 127, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 165.74, max: 358)
#
# Run: 128, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 165.61, max: 358)
#
# Run: 129, exploration: 0.01, score: 149
# Scores: (min: 11, avg: 165.71, max: 358)
#
# Run: 130, exploration: 0.01, score: 207
# Scores: (min: 11, avg: 166.48, max: 358)
#
# Run: 131, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 166.97, max: 358)
#
# Run: 132, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 167.16, max: 358)
#
# Run: 133, exploration: 0.01, score: 216
# Scores: (min: 11, avg: 167.78, max: 358)
#
# Run: 134, exploration: 0.01, score: 134
# Scores: (min: 11, avg: 167.23, max: 358)
#
# Run: 135, exploration: 0.01, score: 137
# Scores: (min: 11, avg: 167.14, max: 358)
#
# Run: 136, exploration: 0.01, score: 106
# Scores: (min: 11, avg: 166.73, max: 358)
#
# Run: 137, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 166.48, max: 358)
#
# Run: 138, exploration: 0.01, score: 200
# Scores: (min: 11, avg: 166.76, max: 358)
#
# Run: 139, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 166.58, max: 358)
#
# Run: 140, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 166.08, max: 358)
#
# Run: 141, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 165.72, max: 358)
#
# Run: 142, exploration: 0.01, score: 426
# Scores: (min: 11, avg: 168.13, max: 426)
#
# Run: 143, exploration: 0.01, score: 236
# Scores: (min: 11, avg: 168.52, max: 426)
#
# Run: 144, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 168.38, max: 426)
#
# Run: 145, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 171.6, max: 500)
#
# Run: 146, exploration: 0.01, score: 185
# Scores: (min: 11, avg: 171.71, max: 500)
#
# Run: 147, exploration: 0.01, score: 209
# Scores: (min: 11, avg: 172.37, max: 500)
#
# Run: 148, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 172.52, max: 500)
#
# Run: 149, exploration: 0.01, score: 119
# Scores: (min: 11, avg: 171.92, max: 500)
#
# Run: 150, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 171.65, max: 500)
#
# Run: 151, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 171.31, max: 500)
#
# Run: 152, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 171.03, max: 500)
#
# Run: 153, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 170.54, max: 500)
#
# Run: 154, exploration: 0.01, score: 158
# Scores: (min: 11, avg: 170.56, max: 500)
#
# Run: 155, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 170.27, max: 500)
#
# Run: 156, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 169.7, max: 500)
#
# Run: 157, exploration: 0.01, score: 52
# Scores: (min: 11, avg: 168.67, max: 500)
#
# Run: 158, exploration: 0.01, score: 117
# Scores: (min: 11, avg: 167.96, max: 500)
#
# Run: 159, exploration: 0.01, score: 183
# Scores: (min: 11, avg: 168.14, max: 500)
#
# Run: 160, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 167.77, max: 500)
#
# Run: 161, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 171.33, max: 500)
#
# Run: 162, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 170.91, max: 500)
#
# Run: 163, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 171.15, max: 500)
#
# Run: 164, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 170.05, max: 500)
#
# Run: 165, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 169.88, max: 500)
#
# Run: 166, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 169.23, max: 500)
#
# Run: 167, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 169.45, max: 500)
#
# Run: 168, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 169.15, max: 500)
#
# Run: 169, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 167.18, max: 500)
#
# Run: 170, exploration: 0.01, score: 417
# Scores: (min: 11, avg: 169.54, max: 500)
#
# Run: 171, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 168.78, max: 500)
#
# Run: 172, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 172.66, max: 500)
#
# Run: 173, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 171.58, max: 500)
#
# Run: 174, exploration: 0.01, score: 324
# Scores: (min: 11, avg: 172.9, max: 500)
#
# Run: 175, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 172.95, max: 500)
#
# Run: 176, exploration: 0.01, score: 129
# Scores: (min: 11, avg: 172.75, max: 500)
#
# Run: 177, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 172.67, max: 500)
#
# Run: 178, exploration: 0.01, score: 302
# Scores: (min: 11, avg: 173.74, max: 500)
#
# Run: 179, exploration: 0.01, score: 218
# Scores: (min: 11, avg: 173.25, max: 500)
#
# Run: 180, exploration: 0.01, score: 158
# Scores: (min: 11, avg: 173.49, max: 500)
#
# Run: 181, exploration: 0.01, score: 119
# Scores: (min: 11, avg: 173.4, max: 500)
#
# Run: 182, exploration: 0.01, score: 96
# Scores: (min: 11, avg: 173.4, max: 500)
#
# Run: 183, exploration: 0.01, score: 164
# Scores: (min: 48, avg: 174.93, max: 500)
#
# Run: 184, exploration: 0.01, score: 500
# Scores: (min: 48, avg: 177.88, max: 500)
#
# Run: 185, exploration: 0.01, score: 500
# Scores: (min: 48, avg: 180.69, max: 500)
#
# Run: 186, exploration: 0.01, score: 360
# Scores: (min: 52, avg: 183.81, max: 500)
#
# Run: 187, exploration: 0.01, score: 208
# Scores: (min: 52, avg: 184.55, max: 500)
#
# Run: 188, exploration: 0.01, score: 252
# Scores: (min: 52, avg: 185.2, max: 500)
# Run: 189, exploration: 0.01, score: 151
# Scores: (min: 52, avg: 185.53, max: 500)
#
# Run: 190, exploration: 0.01, score: 130
# Scores: (min: 52, avg: 183.44, max: 500)
#
# Run: 191, exploration: 0.01, score: 153
# Scores: (min: 52, avg: 183.58, max: 500)
#
# Run: 192, exploration: 0.01, score: 164
# Scores: (min: 52, avg: 183.26, max: 500)
#
# Run: 193, exploration: 0.01, score: 139
# Scores: (min: 52, avg: 183.16, max: 500)
#
# Run: 194, exploration: 0.01, score: 251
# Scores: (min: 52, avg: 183.72, max: 500)
#
# Run: 195, exploration: 0.01, score: 128
# Scores: (min: 52, avg: 182.89, max: 500)
#
# Run: 196, exploration: 0.01, score: 152
# Scores: (min: 52, avg: 182.44, max: 500)
#
# Run: 197, exploration: 0.01, score: 370
# Scores: (min: 52, avg: 184.61, max: 500)
#
# Run: 198, exploration: 0.01, score: 196
# Scores: (min: 52, avg: 185.24, max: 500)
#
# Run: 199, exploration: 0.01, score: 165
# Scores: (min: 52, avg: 185.15, max: 500)
#
# Run: 200, exploration: 0.01, score: 159
# Scores: (min: 52, avg: 185.46, max: 500)
#
# Run: 201, exploration: 0.01, score: 162
# Scores: (min: 52, avg: 185.37, max: 500)
#
# Run: 202, exploration: 0.01, score: 216
# Scores: (min: 52, avg: 186.3, max: 500)
#
# Run: 203, exploration: 0.01, score: 148
# Scores: (min: 52, avg: 186.61, max: 500)
#
# Run: 204, exploration: 0.01, score: 126
# Scores: (min: 52, avg: 186.72, max: 500)
#
# Run: 205, exploration: 0.01, score: 170
# Scores: (min: 52, avg: 186.94, max: 500)
#
# Run: 206, exploration: 0.01, score: 144
# Scores: (min: 52, avg: 187.1, max: 500)
#
# Run: 207, exploration: 0.01, score: 127
# Scores: (min: 52, avg: 187.07, max: 500)
#
# Run: 208, exploration: 0.01, score: 121
# Scores: (min: 52, avg: 187.04, max: 500)
#
# Run: 209, exploration: 0.01, score: 108
# Scores: (min: 52, avg: 186.48, max: 500)
#
# Run: 210, exploration: 0.01, score: 73
# Scores: (min: 52, avg: 185.45, max: 500)
#
# Run: 211, exploration: 0.01, score: 193
# Scores: (min: 52, avg: 185.28, max: 500)
#
# Run: 212, exploration: 0.01, score: 179
# Scores: (min: 52, avg: 185.41, max: 500)
#
# Run: 213, exploration: 0.01, score: 143
# Scores: (min: 52, avg: 185.52, max: 500)
#
# Run: 214, exploration: 0.01, score: 154
# Scores: (min: 52, avg: 185.63, max: 500)
#
# Run: 215, exploration: 0.01, score: 195
# Scores: (min: 52, avg: 185.99, max: 500)
#
# Run: 216, exploration: 0.01, score: 114
# Scores: (min: 52, avg: 185.78, max: 500)
#
# Run: 217, exploration: 0.01, score: 367
# Scores: (min: 52, avg: 187.31, max: 500)
#
# Run: 218, exploration: 0.01, score: 89
# Scores: (min: 52, avg: 186.9, max: 500)
#
# Run: 219, exploration: 0.01, score: 161
# Scores: (min: 52, avg: 185.63, max: 500)
#
# Run: 220, exploration: 0.01, score: 113
# Scores: (min: 52, avg: 184.22, max: 500)
#
# Run: 221, exploration: 0.01, score: 154
# Scores: (min: 52, avg: 184.48, max: 500)
#
# Run: 222, exploration: 0.01, score: 238
# Scores: (min: 52, avg: 185.19, max: 500)
#
# Run: 223, exploration: 0.01, score: 155
# Scores: (min: 52, avg: 185.5, max: 500)
#
# Run: 224, exploration: 0.01, score: 152
# Scores: (min: 52, avg: 184.98, max: 500)
#
# Run: 225, exploration: 0.01, score: 153
# Scores: (min: 52, avg: 185.05, max: 500)
#
# Run: 226, exploration: 0.01, score: 122
# Scores: (min: 52, avg: 184.03, max: 500)
#
# Run: 227, exploration: 0.01, score: 25
# Scores: (min: 25, avg: 182.95, max: 500)
#
# Run: 228, exploration: 0.01, score: 122
# Scores: (min: 25, avg: 183.02, max: 500)
#
# Run: 229, exploration: 0.01, score: 442
# Scores: (min: 25, avg: 185.95, max: 500)
#
# Run: 230, exploration: 0.01, score: 96
# Scores: (min: 25, avg: 184.84, max: 500)
#
# Run: 231, exploration: 0.01, score: 129
# Scores: (min: 25, avg: 184.61, max: 500)
#
# Run: 232, exploration: 0.01, score: 49
# Scores: (min: 25, avg: 183.54, max: 500)
#
# Run: 233, exploration: 0.01, score: 105
# Scores: (min: 25, avg: 182.43, max: 500)
#
# Run: 234, exploration: 0.01, score: 500
# Scores: (min: 25, avg: 186.09, max: 500)
#
# Run: 235, exploration: 0.01, score: 133
# Scores: (min: 25, avg: 186.05, max: 500)
#
# Run: 236, exploration: 0.01, score: 26
# Scores: (min: 25, avg: 185.25, max: 500)
#
# Run: 237, exploration: 0.01, score: 114
# Scores: (min: 25, avg: 185.13, max: 500)
#
# Run: 238, exploration: 0.01, score: 198
# Scores: (min: 25, avg: 185.11, max: 500)
#
# Run: 239, exploration: 0.01, score: 106
# Scores: (min: 25, avg: 184.74, max: 500)
#
# Run: 240, exploration: 0.01, score: 105
# Scores: (min: 25, avg: 184.13, max: 500)
#
# Run: 241, exploration: 0.01, score: 119
# Scores: (min: 25, avg: 184.02, max: 500)
#
# Run: 242, exploration: 0.01, score: 37
# Scores: (min: 25, avg: 180.13, max: 500)
#
# Run: 243, exploration: 0.01, score: 29
# Scores: (min: 25, avg: 178.06, max: 500)
#
# Run: 244, exploration: 0.01, score: 23
# Scores: (min: 23, avg: 176.82, max: 500)
#
# Run: 245, exploration: 0.01, score: 181
# Scores: (min: 23, avg: 173.63, max: 500)
#
# Run: 246, exploration: 0.01, score: 445
# Scores: (min: 23, avg: 176.23, max: 500)
#
# Run: 247, exploration: 0.01, score: 147
# Scores: (min: 23, avg: 175.61, max: 500)
#
# Run: 248, exploration: 0.01, score: 117
# Scores: (min: 23, avg: 175.02, max: 500)
#
# Run: 249, exploration: 0.01, score: 147
# Scores: (min: 23, avg: 175.3, max: 500)
#
# Run: 250, exploration: 0.01, score: 231
# Scores: (min: 23, avg: 176.16, max: 500)
#
# Run: 251, exploration: 0.01, score: 126
# Scores: (min: 23, avg: 175.9, max: 500)
#
# Run: 252, exploration: 0.01, score: 490
# Scores: (min: 23, avg: 179.49, max: 500)
#
# Run: 253, exploration: 0.01, score: 134
# Scores: (min: 23, avg: 179.63, max: 500)
#
# Run: 254, exploration: 0.01, score: 182
# Scores: (min: 23, avg: 179.87, max: 500)
#
# Run: 255, exploration: 0.01, score: 120
# Scores: (min: 23, avg: 179.71, max: 500)
#
# Run: 256, exploration: 0.01, score: 106
# Scores: (min: 23, avg: 179.74, max: 500)
#
# Run: 257, exploration: 0.01, score: 345
# Scores: (min: 23, avg: 182.67, max: 500)
#
# Run: 258, exploration: 0.01, score: 500
# Scores: (min: 23, avg: 186.5, max: 500)
#
# Run: 259, exploration: 0.01, score: 190
# Scores: (min: 23, avg: 186.57, max: 500)
#
# Run: 260, exploration: 0.01, score: 197
# Scores: (min: 23, avg: 187.44, max: 500)
#
# Run: 261, exploration: 0.01, score: 183
# Scores: (min: 23, avg: 184.27, max: 500)
#
# Run: 262, exploration: 0.01, score: 214
# Scores: (min: 23, avg: 184.81, max: 500)
#
# Run: 263, exploration: 0.01, score: 198
# Scores: (min: 23, avg: 185.15, max: 500)
#
# Run: 264, exploration: 0.01, score: 156
# Scores: (min: 23, avg: 185.49, max: 500)
#
# Run: 265, exploration: 0.01, score: 120
# Scores: (min: 23, avg: 185.59, max: 500)
#
# Run: 266, exploration: 0.01, score: 143
# Scores: (min: 23, avg: 185.87, max: 500)
#
# Run: 267, exploration: 0.01, score: 211
# Scores: (min: 23, avg: 186.28, max: 500)
#
# Run: 268, exploration: 0.01, score: 115
# Scores: (min: 23, avg: 185.76, max: 500)
#
# Run: 269, exploration: 0.01, score: 137
# Scores: (min: 23, avg: 185.52, max: 500)
#
# Run: 270, exploration: 0.01, score: 159
# Scores: (min: 23, avg: 182.94, max: 500)
#
# Run: 271, exploration: 0.01, score: 500
# Scores: (min: 23, avg: 186.2, max: 500)
#
# Run: 272, exploration: 0.01, score: 490
# Scores: (min: 23, avg: 186.1, max: 500)
#
# Run: 273, exploration: 0.01, score: 136
# Scores: (min: 23, avg: 186.14, max: 500)
#
# Run: 274, exploration: 0.01, score: 222
# Scores: (min: 23, avg: 185.12, max: 500)
#
# Run: 275, exploration: 0.01, score: 126
# Scores: (min: 23, avg: 184.99, max: 500)
#
# Run: 276, exploration: 0.01, score: 110
# Scores: (min: 23, avg: 184.8, max: 500)
#
# Run: 277, exploration: 0.01, score: 31
# Scores: (min: 23, avg: 183.79, max: 500)
#
# Run: 278, exploration: 0.01, score: 15
# Scores: (min: 15, avg: 180.92, max: 500)
#
# Run: 279, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 178.86, max: 500)
#
# Run: 280, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 177.4, max: 500)
#
# Run: 281, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 176.34, max: 500)
#
# Run: 282, exploration: 0.01, score: 147
# Scores: (min: 12, avg: 176.85, max: 500)
#
# Run: 283, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 176.32, max: 500)
#
# Run: 284, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 176.32, max: 500)
#
# Run: 285, exploration: 0.01, score: 195
# Scores: (min: 12, avg: 173.27, max: 500)
#
# Run: 286, exploration: 0.01, score: 192
# Scores: (min: 12, avg: 171.59, max: 500)
#
# Run: 287, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 170.8, max: 500)
#
# Run: 288, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 169.33, max: 500)
#
# Run: 289, exploration: 0.01, score: 244
# Scores: (min: 12, avg: 170.26, max: 500)
# Run: 290, exploration: 0.01, score: 251
# Scores: (min: 12, avg: 171.47, max: 500)
#
# Run: 291, exploration: 0.01, score: 200
# Scores: (min: 12, avg: 171.94, max: 500)
#
# Run: 292, exploration: 0.01, score: 297
# Scores: (min: 12, avg: 173.27, max: 500)
#
# Run: 293, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 172.84, max: 500)
#
# Run: 294, exploration: 0.01, score: 242
# Scores: (min: 12, avg: 172.75, max: 500)
#
# Run: 295, exploration: 0.01, score: 178
# Scores: (min: 12, avg: 173.25, max: 500)
#
# Run: 296, exploration: 0.01, score: 102
# Scores: (min: 12, avg: 172.75, max: 500)
#
# Run: 297, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 170.41, max: 500)
#
# Run: 298, exploration: 0.01, score: 161
# Scores: (min: 12, avg: 170.06, max: 500)
#
# Run: 299, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 169.65, max: 500)
#
# Run: 300, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 169.57, max: 500)
#
# Run: 301, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 169.68, max: 500)
#
# Run: 302, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 168.43, max: 500)
#
# Run: 303, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 167.08, max: 500)
#
# Run: 304, exploration: 0.01, score: 94
# Scores: (min: 12, avg: 166.76, max: 500)
#
# Run: 305, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 166.02, max: 500)
#
# Run: 306, exploration: 0.01, score: 59
# Scores: (min: 12, avg: 165.17, max: 500)
#
# Run: 307, exploration: 0.01, score: 63
# Scores: (min: 12, avg: 164.53, max: 500)
#
# Run: 308, exploration: 0.01, score: 64
# Scores: (min: 12, avg: 163.96, max: 500)
#
# Run: 309, exploration: 0.01, score: 54
# Scores: (min: 12, avg: 163.42, max: 500)
#
# Run: 310, exploration: 0.01, score: 78
# Scores: (min: 12, avg: 163.47, max: 500)
#
# Run: 311, exploration: 0.01, score: 170
# Scores: (min: 12, avg: 163.24, max: 500)
#
# Run: 312, exploration: 0.01, score: 454
# Scores: (min: 12, avg: 165.99, max: 500)
#
# Run: 313, exploration: 0.01, score: 100
# Scores: (min: 12, avg: 165.56, max: 500)
#
# Run: 314, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 165.32, max: 500)
#
# Run: 315, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 164.56, max: 500)
#
# Run: 316, exploration: 0.01, score: 95
# Scores: (min: 12, avg: 164.37, max: 500)
#
# Run: 317, exploration: 0.01, score: 492
# Scores: (min: 12, avg: 165.62, max: 500)
#
# Run: 318, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 165.91, max: 500)
#
# Run: 319, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 165.39, max: 500)
#
# Run: 320, exploration: 0.01, score: 97
# Scores: (min: 12, avg: 165.23, max: 500)
#
# Run: 321, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 164.84, max: 500)
#
# Run: 322, exploration: 0.01, score: 161
# Scores: (min: 12, avg: 164.07, max: 500)
#
# Run: 323, exploration: 0.01, score: 346
# Scores: (min: 12, avg: 165.98, max: 500)
#
# Run: 324, exploration: 0.01, score: 147
# Scores: (min: 12, avg: 165.93, max: 500)
#
# Run: 325, exploration: 0.01, score: 230
# Scores: (min: 12, avg: 166.7, max: 500)
#
# Run: 326, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 166.68, max: 500)
#
# Run: 327, exploration: 0.01, score: 194
# Scores: (min: 12, avg: 168.37, max: 500)
#
# Run: 328, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 168.53, max: 500)
#
# Run: 329, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 165.07, max: 500)
#
# Run: 330, exploration: 0.01, score: 92
# Scores: (min: 12, avg: 165.03, max: 500)
#
# Run: 331, exploration: 0.01, score: 85
# Scores: (min: 12, avg: 164.59, max: 500)
#
# Run: 332, exploration: 0.01, score: 49
# Scores: (min: 12, avg: 164.59, max: 500)
#
# Run: 333, exploration: 0.01, score: 40
# Scores: (min: 12, avg: 163.94, max: 500)
#
# Run: 334, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 160.27, max: 500)
#
# Run: 335, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 160.27, max: 500)
#
# Run: 336, exploration: 0.01, score: 205
# Scores: (min: 12, avg: 162.06, max: 500)
#
# Run: 337, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 162.17, max: 500)
#
# Run: 338, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 161.36, max: 500)
#
# Run: 339, exploration: 0.01, score: 305
# Scores: (min: 12, avg: 163.35, max: 500)
#
# Run: 340, exploration: 0.01, score: 204
# Scores: (min: 12, avg: 164.34, max: 500)
#
# Run: 341, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 164.55, max: 500)
#
# Run: 342, exploration: 0.01, score: 227
# Scores: (min: 12, avg: 166.45, max: 500)
#
# Run: 343, exploration: 0.01, score: 84
# Scores: (min: 12, avg: 167, max: 500)
#
# Run: 344, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 166.93, max: 500)
#
# Run: 345, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 165.21, max: 500)
#
# Run: 346, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 160.85, max: 500)
#
# Run: 347, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 159.5, max: 500)
#
# Run: 348, exploration: 0.01, score: 391
# Scores: (min: 9, avg: 162.24, max: 500)
#
# Run: 349, exploration: 0.01, score: 254
# Scores: (min: 9, avg: 163.31, max: 500)
#
# Run: 350, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 162.14, max: 500)
#
# Run: 351, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 163.08, max: 500)
#
# Run: 352, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 158.88, max: 500)
#
# Run: 353, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 158, max: 500)
#
# Run: 354, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 157.59, max: 500)
#
# Run: 355, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 157.78, max: 500)
#
# Run: 356, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 157.9, max: 500)
#
# Run: 357, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 155.54, max: 500)
#
# Run: 358, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 152.28, max: 500)
#
# Run: 359, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 151.45, max: 500)
#
# Run: 360, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 151.16, max: 500)
#
# Run: 361, exploration: 0.01, score: 305
# Scores: (min: 9, avg: 152.38, max: 500)
#
# Run: 362, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 153.16, max: 500)
#
# Run: 363, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 156.18, max: 500)
#
# Run: 364, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 155.82, max: 500)
#
# Run: 365, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 156.11, max: 500)
#
# Run: 366, exploration: 0.01, score: 371
# Scores: (min: 9, avg: 158.39, max: 500)
#
# Run: 367, exploration: 0.01, score: 247
# Scores: (min: 9, avg: 158.75, max: 500)
#
# Run: 368, exploration: 0.01, score: 330
# Scores: (min: 9, avg: 160.9, max: 500)
#
# Run: 369, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 160.84, max: 500)
#
# Run: 370, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 161.24, max: 500)
#
# Run: 371, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 157.58, max: 500)
#
# Run: 372, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 153.67, max: 500)
#
# Run: 373, exploration: 0.01, score: 181
# Scores: (min: 9, avg: 154.12, max: 500)
#
# Run: 374, exploration: 0.01, score: 291
# Scores: (min: 9, avg: 154.81, max: 500)
#
# Run: 375, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 155.32, max: 500)
#
# Run: 376, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 156.29, max: 500)
#
# Run: 377, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 157.43, max: 500)
#
# Run: 378, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 158.36, max: 500)
#
# Run: 379, exploration: 0.01, score: 313
# Scores: (min: 9, avg: 161.37, max: 500)
#
# Run: 380, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 162.84, max: 500)
#
# Run: 381, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 164.04, max: 500)
#
# Run: 382, exploration: 0.01, score: 294
# Scores: (min: 9, avg: 165.51, max: 500)
#
# Run: 383, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 166.41, max: 500)
#
# Run: 384, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 162.69, max: 500)
#
# Run: 385, exploration: 0.01, score: 255
# Scores: (min: 9, avg: 163.29, max: 500)
#
# Run: 386, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 162.53, max: 500)
#
# Run: 387, exploration: 0.01, score: 254
# Scores: (min: 9, avg: 163.78, max: 500)
#
# Run: 388, exploration: 0.01, score: 282
# Scores: (min: 9, avg: 165.55, max: 500)
#
# Run: 389, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 165.05, max: 500)
#
# Run: 390, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 164.06, max: 500)
# Run: 391, exploration: 0.01, score: 468
# Scores: (min: 9, avg: 166.74, max: 500)
#
# Run: 392, exploration: 0.01, score: 358
# Scores: (min: 9, avg: 167.35, max: 500)
#
# Run: 393, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 168.45, max: 500)
#
# Run: 394, exploration: 0.01, score: 96
# Scores: (min: 9, avg: 166.99, max: 500)
#
# Run: 395, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 166.21, max: 500)
#
# Run: 396, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 166.99, max: 500)
#
# Run: 397, exploration: 0.01, score: 281
# Scores: (min: 9, avg: 168.44, max: 500)
#
# Run: 398, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 169.12, max: 500)
#
# Run: 399, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 169.93, max: 500)
#
# Run: 400, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 169.81, max: 500)
#
# Run: 401, exploration: 0.01, score: 244
# Scores: (min: 9, avg: 170.52, max: 500)
#
# Run: 402, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 171.59, max: 500)
#
# Run: 403, exploration: 0.01, score: 345
# Scores: (min: 9, avg: 174.91, max: 500)
#
# Run: 404, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 175.12, max: 500)
#
# Run: 405, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 176.59, max: 500)
#
# Run: 406, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 178.18, max: 500)
#
# Run: 407, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 179.16, max: 500)
#
# Run: 408, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 180.69, max: 500)
#
# Run: 409, exploration: 0.01, score: 294
# Scores: (min: 9, avg: 183.09, max: 500)
#
# Run: 410, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 184.21, max: 500)
#
# Run: 411, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 183.52, max: 500)
#
# Run: 412, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 180.08, max: 500)
#
# Run: 413, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 181.01, max: 500)
#
# Run: 414, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 179.82, max: 500)
#
# Run: 415, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 180.4, max: 500)
#
# Run: 416, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 181.15, max: 500)
#
# Run: 417, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 177.51, max: 500)
#
# Run: 418, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 178.67, max: 500)
#
# Run: 419, exploration: 0.01, score: 416
# Scores: (min: 9, avg: 181.74, max: 500)
#
# Run: 420, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 181.86, max: 500)
#
# Run: 421, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 181.76, max: 500)
#
# Run: 422, exploration: 0.01, score: 284
# Scores: (min: 9, avg: 182.99, max: 500)
#
# Run: 423, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 180.6, max: 500)
#
# Run: 424, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 180.39, max: 500)
#
# Run: 425, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 179.11, max: 500)
#
# Run: 426, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 179.4, max: 500)
#
# Run: 427, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 178.59, max: 500)
#
# Run: 428, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 178.95, max: 500)
#
# Run: 429, exploration: 0.01, score: 409
# Scores: (min: 9, avg: 182.08, max: 500)
#
# Run: 430, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 182.72, max: 500)
#
# Run: 431, exploration: 0.01, score: 265
# Scores: (min: 9, avg: 184.52, max: 500)
#
# Run: 432, exploration: 0.01, score: 378
# Scores: (min: 9, avg: 187.81, max: 500)
#
# Run: 433, exploration: 0.01, score: 446
# Scores: (min: 9, avg: 191.87, max: 500)
#
# Run: 434, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 191.61, max: 500)
#
# Run: 435, exploration: 0.01, score: 385
# Scores: (min: 9, avg: 194.13, max: 500)
#
# Run: 436, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 193.42, max: 500)
#
# Run: 437, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 193.92, max: 500)
#
# Run: 438, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 197.75, max: 500)
#
# Solved in 338 runs, 438 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.99  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 30  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.1  
EXPLORATION_DECAY = 0.95  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 11
# Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.7737809374999999, score: 24
# Scores: (min: 11, avg: 17.5, max: 24)
#
# Run: 3, exploration: 0.1, score: 53
# Scores: (min: 11, avg: 29.333333333333332, max: 53)
#
# Run: 4, exploration: 0.1, score: 15
# Scores: (min: 11, avg: 25.75, max: 53)
#
# Run: 5, exploration: 0.1, score: 29
# Scores: (min: 11, avg: 26.4, max: 53)
#
# Run: 6, exploration: 0.1, score: 57
# Scores: (min: 11, avg: 31.5, max: 57)
#
# Run: 7, exploration: 0.1, score: 19
# Scores: (min: 11, avg: 29.714285714285715, max: 57)
#
# Run: 8, exploration: 0.1, score: 63
# Scores: (min: 11, avg: 33.875, max: 63)
#
# Run: 9, exploration: 0.1, score: 36
# Scores: (min: 11, avg: 34.111111111111114, max: 63)
#
# Run: 10, exploration: 0.1, score: 51
# Scores: (min: 11, avg: 35.8, max: 63)
#
# Run: 11, exploration: 0.1, score: 109
# Scores: (min: 11, avg: 42.45454545454545, max: 109)
#
# Run: 12, exploration: 0.1, score: 67
# Scores: (min: 11, avg: 44.5, max: 109)
#
# Run: 13, exploration: 0.1, score: 100
# Scores: (min: 11, avg: 48.76923076923077, max: 109)
#
# Run: 14, exploration: 0.1, score: 95
# Scores: (min: 11, avg: 52.07142857142857, max: 109)
#
# Run: 15, exploration: 0.1, score: 96
# Scores: (min: 11, avg: 55, max: 109)
#
# Run: 16, exploration: 0.1, score: 84
# Scores: (min: 11, avg: 56.8125, max: 109)
#
# Run: 17, exploration: 0.1, score: 113
# Scores: (min: 11, avg: 60.11764705882353, max: 113)
#
# Run: 18, exploration: 0.1, score: 135
# Scores: (min: 11, avg: 64.27777777777777, max: 135)
#
# Run: 19, exploration: 0.1, score: 383
# Scores: (min: 11, avg: 81.05263157894737, max: 383)
#
# Run: 20, exploration: 0.1, score: 183
# Scores: (min: 11, avg: 86.15, max: 383)
#
# Run: 21, exploration: 0.1, score: 346
# Scores: (min: 11, avg: 98.52380952380952, max: 383)
#
# Run: 22, exploration: 0.1, score: 244
# Scores: (min: 11, avg: 105.13636363636364, max: 383)
#
# Run: 23, exploration: 0.1, score: 272
# Scores: (min: 11, avg: 112.3913043478261, max: 383)
#
# Run: 24, exploration: 0.1, score: 489
# Scores: (min: 11, avg: 128.08333333333334, max: 489)
#
# Run: 25, exploration: 0.1, score: 288
# Scores: (min: 11, avg: 134.48, max: 489)
#
# Run: 26, exploration: 0.1, score: 500
# Scores: (min: 11, avg: 148.53846153846155, max: 500)
#
# Run: 27, exploration: 0.1, score: 500
# Scores: (min: 11, avg: 161.55555555555554, max: 500)
#
# Run: 28, exploration: 0.1, score: 351
# Scores: (min: 11, avg: 168.32142857142858, max: 500)
#
# Run: 29, exploration: 0.1, score: 277
# Scores: (min: 11, avg: 172.06896551724137, max: 500)
#
# Run: 30, exploration: 0.1, score: 246
# Scores: (min: 11, avg: 174.53333333333333, max: 500)
#
# Run: 31, exploration: 0.1, score: 233
# Scores: (min: 11, avg: 176.41935483870967, max: 500)
#
# Run: 32, exploration: 0.1, score: 233
# Scores: (min: 11, avg: 178.1875, max: 500)
#
# Run: 33, exploration: 0.1, score: 185
# Scores: (min: 11, avg: 178.3939393939394, max: 500)
#
# Run: 34, exploration: 0.1, score: 190
# Scores: (min: 11, avg: 178.73529411764707, max: 500)
#
# Run: 35, exploration: 0.1, score: 177
# Scores: (min: 11, avg: 178.68571428571428, max: 500)
#
# Run: 36, exploration: 0.1, score: 175
# Scores: (min: 11, avg: 178.58333333333334, max: 500)
#
# Run: 37, exploration: 0.1, score: 159
# Scores: (min: 11, avg: 178.05405405405406, max: 500)
#
# Run: 38, exploration: 0.1, score: 126
# Scores: (min: 11, avg: 176.68421052631578, max: 500)
#
# Run: 39, exploration: 0.1, score: 118
# Scores: (min: 11, avg: 175.17948717948718, max: 500)
#
# Run: 40, exploration: 0.1, score: 312
# Scores: (min: 11, avg: 178.6, max: 500)
#
# Run: 41, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 174.46341463414635, max: 500)
#
# Run: 42, exploration: 0.1, score: 12
# Scores: (min: 9, avg: 170.5952380952381, max: 500)
#
# Run: 43, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 166.86046511627907, max: 500)
#
# Run: 44, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 163.27272727272728, max: 500)
#
# Run: 45, exploration: 0.1, score: 12
# Scores: (min: 9, avg: 159.9111111111111, max: 500)
#
# Run: 46, exploration: 0.1, score: 208
# Scores: (min: 9, avg: 160.95652173913044, max: 500)
#
# Run: 47, exploration: 0.1, score: 105
# Scores: (min: 9, avg: 159.7659574468085, max: 500)
#
# Run: 48, exploration: 0.1, score: 34
# Scores: (min: 9, avg: 157.14583333333334, max: 500)
#
# Run: 49, exploration: 0.1, score: 201
# Scores: (min: 9, avg: 158.0408163265306, max: 500)
#
# Run: 50, exploration: 0.1, score: 158
# Scores: (min: 9, avg: 158.04, max: 500)
#
# Run: 51, exploration: 0.1, score: 90
# Scores: (min: 9, avg: 156.7058823529412, max: 500)
#
# Run: 52, exploration: 0.1, score: 62
# Scores: (min: 9, avg: 154.8846153846154, max: 500)
#
# Run: 53, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 152.1509433962264, max: 500)
#
# Run: 54, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 149.5185185185185, max: 500)
#
# Run: 55, exploration: 0.1, score: 41
# Scores: (min: 9, avg: 147.54545454545453, max: 500)
#
# Run: 56, exploration: 0.1, score: 500
# Scores: (min: 9, avg: 153.83928571428572, max: 500)
#
# Run: 57, exploration: 0.1, score: 203
# Scores: (min: 9, avg: 154.7017543859649, max: 500)
#
# Run: 58, exploration: 0.1, score: 500
# Scores: (min: 9, avg: 160.6551724137931, max: 500)
#
# Run: 59, exploration: 0.1, score: 482
# Scores: (min: 9, avg: 166.10169491525423, max: 500)
#
# Run: 60, exploration: 0.1, score: 500
# Scores: (min: 9, avg: 171.66666666666666, max: 500)
#
# Run: 61, exploration: 0.1, score: 196
# Scores: (min: 9, avg: 172.0655737704918, max: 500)
#
# Run: 62, exploration: 0.1, score: 500
# Scores: (min: 9, avg: 177.3548387096774, max: 500)
#
# Run: 63, exploration: 0.1, score: 274
# Scores: (min: 9, avg: 178.88888888888889, max: 500)
#
# Run: 64, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 176.25, max: 500)
#
# Run: 65, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 173.69230769230768, max: 500)
#
# Run: 66, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 171.21212121212122, max: 500)
#
# Run: 67, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 168.7910447761194, max: 500)
#
# Run: 68, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 166.4558823529412, max: 500)
#
# Run: 69, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 164.18840579710144, max: 500)
#
# Run: 70, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 161.97142857142856, max: 500)
#
# Run: 71, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 159.81690140845072, max: 500)
#
# Run: 72, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 157.72222222222223, max: 500)
#
# Run: 73, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 155.6986301369863, max: 500)
#
# Run: 74, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 153.71621621621622, max: 500)
#
# Run: 75, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 151.77333333333334, max: 500)
#
# Run: 76, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 149.9078947368421, max: 500)
#
# Run: 77, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 148.11688311688312, max: 500)
#
# Run: 78, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 146.3846153846154, max: 500)
#
# Run: 79, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 144.68354430379748, max: 500)
#
# Run: 80, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 142.9875, max: 500)
#
# Run: 81, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 141.320987654321, max: 500)
#
# Run: 82, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 139.71951219512195, max: 500)
#
# Run: 83, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 138.13253012048193, max: 500)
#
# Run: 84, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 136.5952380952381, max: 500)
#
# Run: 85, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 135.09411764705882, max: 500)
#
# Run: 86, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 133.63953488372093, max: 500)
#
# Run: 87, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 132.2183908045977, max: 500)
#
# Run: 88, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 130.86363636363637, max: 500)
#
# Run: 89, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 129.5056179775281, max: 500)
#
# Run: 90, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 128.17777777777778, max: 500)
#
# Run: 91, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 126.87912087912088, max: 500)
#
# Run: 92, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 125.59782608695652, max: 500)
#
# Run: 93, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 124.35483870967742, max: 500)
#
# Run: 94, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 123.13829787234043, max: 500)
# Run: 95, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 121.93684210526315, max: 500)
#
# Run: 96, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 120.76041666666667, max: 500)
#
# Run: 97, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 119.62886597938144, max: 500)
#
# Run: 98, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 118.51020408163265, max: 500)
#
# Run: 99, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 117.4040404040404, max: 500)
#
# Run: 100, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 116.32, max: 500)
#
# Run: 101, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 116.32, max: 500)
#
# Run: 102, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 116.16, max: 500)
#
# Run: 103, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 115.73, max: 500)
#
# Run: 104, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 115.68, max: 500)
#
# Run: 105, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 115.48, max: 500)
#
# Run: 106, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 115.01, max: 500)
#
# Run: 107, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 114.9, max: 500)
#
# Run: 108, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 114.35, max: 500)
#
# Run: 109, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 114.09, max: 500)
#
# Run: 110, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 113.68, max: 500)
#
# Run: 111, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 112.69, max: 500)
#
# Run: 112, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 112.15, max: 500)
#
# Run: 113, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 111.25, max: 500)
#
# Run: 114, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 110.38, max: 500)
#
# Run: 115, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 109.51, max: 500)
#
# Run: 116, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 108.77, max: 500)
#
# Run: 117, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 107.75, max: 500)
#
# Run: 118, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 106.51, max: 500)
#
# Run: 119, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 102.78, max: 500)
#
# Run: 120, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 101.04, max: 500)
#
# Run: 121, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 97.69, max: 500)
#
# Run: 122, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 95.34, max: 500)
#
# Run: 123, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 92.7, max: 500)
#
# Run: 124, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 87.93, max: 500)
#
# Run: 125, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 85.16, max: 500)
#
# Run: 126, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 80.25, max: 500)
#
# Run: 127, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 75.36, max: 500)
#
# Run: 128, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 71.95, max: 500)
#
# Run: 129, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 69.27, max: 500)
#
# Run: 130, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 66.94, max: 500)
#
# Run: 131, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 64.71, max: 500)
#
# Run: 132, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 62.48, max: 500)
#
# Run: 133, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 60.71, max: 500)
#
# Run: 134, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 58.91, max: 500)
#
# Run: 135, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 57.26, max: 500)
#
# Run: 136, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 55.61, max: 500)
#
# Run: 137, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 54.12, max: 500)
#
# Run: 138, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 52.95, max: 500)
#
# Run: 139, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 51.86, max: 500)
#
# Run: 140, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 48.83, max: 500)
#
# Run: 141, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 48.83, max: 500)
#
# Run: 142, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 48.81, max: 500)
#
# Run: 143, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 48.8, max: 500)
#
# Run: 144, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 48.81, max: 500)
#
# Run: 145, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 48.77, max: 500)
#
# Run: 146, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 46.79, max: 500)
#
# Run: 147, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 45.83, max: 500)
#
# Run: 148, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 45.58, max: 500)
#
# Run: 149, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 43.67, max: 500)
#
# Run: 150, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 42.17, max: 500)
#
# Run: 151, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 41.37, max: 500)
#
# Run: 152, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 40.85, max: 500)
#
# Run: 153, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 40.84, max: 500)
#
# Run: 154, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 40.84, max: 500)
#
# Run: 155, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 40.54, max: 500)
#
# Run: 156, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 35.67, max: 500)
#
# Run: 157, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 33.74, max: 500)
#
# Run: 158, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 28.83, max: 500)
#
# Run: 159, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 24.14, max: 500)
#
# Run: 160, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 19.26, max: 500)
#
# Run: 161, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 17.39, max: 500)
#
# Run: 162, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 12.49, max: 274)
#
# Run: 163, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 164, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 165, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 166, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 167, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 168, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 169, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 170, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 171, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 172, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 173, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.88, max: 13)
#
# Run: 174, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 175, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.9, max: 13)
#
# Run: 176, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.91, max: 13)
#
# Run: 177, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 178, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 179, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 180, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.83, max: 13)
#
# Run: 181, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 182, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.87, max: 13)
#
# Run: 183, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.88, max: 13)
#
# Run: 184, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 185, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 186, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.88, max: 13)
#
# Run: 187, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.87, max: 13)
#
# Run: 188, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.83, max: 13)
#
# Run: 189, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 190, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 191, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.82, max: 13)
#
# Run: 192, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.83, max: 13)
#
# Run: 193, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 194, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 195, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 196, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 197, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 198, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.83, max: 13)
#
# Run: 199, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 200, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.87, max: 13)
# Run: 201, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 202, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 9.9, max: 13)
#
# Run: 203, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.9, max: 13)
#
# Run: 204, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.91, max: 13)
#
# Run: 205, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.92, max: 13)
#
# Run: 206, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.91, max: 13)
#
# Run: 207, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.93, max: 13)
#
# Run: 208, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.95, max: 13)
#
# Run: 209, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.96, max: 13)
#
# Run: 210, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.95, max: 13)
#
# Run: 211, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.93, max: 13)
#
# Run: 212, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.9, max: 13)
#
# Run: 213, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 214, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.91, max: 13)
#
# Run: 215, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.92, max: 13)
#
# Run: 216, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 9.94, max: 13)
#
# Run: 217, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.92, max: 13)
#
# Run: 218, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.9, max: 13)
#
# Run: 219, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 220, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.89, max: 13)
#
# Run: 221, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.88, max: 13)
#
# Run: 222, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.88, max: 13)
#
# Run: 223, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.88, max: 13)
#
# Run: 224, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 225, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 226, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 227, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.81, max: 13)
#
# Run: 228, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.81, max: 13)
#
# Run: 229, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.81, max: 13)
#
# Run: 230, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.77, max: 13)
#
# Run: 231, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.76, max: 13)
#
# Run: 232, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.76, max: 13)
#
# Run: 233, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.78, max: 13)
#
# Run: 234, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 235, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.77, max: 13)
#
# Run: 236, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.78, max: 13)
#
# Run: 237, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 238, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.81, max: 13)
#
# Run: 239, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.82, max: 13)
#
# Run: 240, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.82, max: 13)
#
# Run: 241, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.83, max: 13)
#
# Run: 242, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 243, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 244, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.83, max: 13)
#
# Run: 245, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 246, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 247, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 248, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.83, max: 13)
#
# Run: 249, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 250, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 251, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.86, max: 13)
#
# Run: 252, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 253, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.85, max: 13)
#
# Run: 254, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 9.87, max: 13)
#
# Run: 255, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.84, max: 13)
#
# Run: 256, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.82, max: 13)
#
# Run: 257, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.81, max: 13)
#
# Run: 258, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.82, max: 13)
#
# Run: 259, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 260, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.77, max: 13)
#
# Run: 261, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.77, max: 13)
#
# Run: 262, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.76, max: 13)
#
# Run: 263, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.76, max: 13)
#
# Run: 264, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.76, max: 13)
#
# Run: 265, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.76, max: 13)
#
# Run: 266, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.78, max: 13)
#
# Run: 267, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.79, max: 13)
#
# Run: 268, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.79, max: 13)
#
# Run: 269, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.77, max: 13)
#
# Run: 270, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 9.76, max: 13)
#
# Run: 271, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.74, max: 13)
#
# Run: 272, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 9.77, max: 13)
#
# Run: 273, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 274, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 275, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 276, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 277, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.81, max: 13)
#
# Run: 278, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 279, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 280, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 9.82, max: 13)
#
# Run: 281, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 282, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.8, max: 13)
#
# Run: 283, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.82, max: 13)
#
# Run: 284, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 9.83, max: 13)
#
# Run: 285, exploration: 0.1, score: 38
# Scores: (min: 8, avg: 10.12, max: 38)
#
# Run: 286, exploration: 0.1, score: 113
# Scores: (min: 8, avg: 11.16, max: 113)
#
# Run: 287, exploration: 0.1, score: 59
# Scores: (min: 8, avg: 11.66, max: 113)
#
# Run: 288, exploration: 0.1, score: 25
# Scores: (min: 8, avg: 11.82, max: 113)
#
# Run: 289, exploration: 0.1, score: 22
# Scores: (min: 8, avg: 11.93, max: 113)
#
# Run: 290, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 12.1, max: 113)
#
# Run: 291, exploration: 0.1, score: 41
# Scores: (min: 8, avg: 12.43, max: 113)
#
# Run: 292, exploration: 0.1, score: 52
# Scores: (min: 8, avg: 12.85, max: 113)
#
# Run: 293, exploration: 0.1, score: 50
# Scores: (min: 8, avg: 13.24, max: 113)
#
# Run: 294, exploration: 0.1, score: 42
# Scores: (min: 8, avg: 13.56, max: 113)
#
# Run: 295, exploration: 0.1, score: 38
# Scores: (min: 8, avg: 13.84, max: 113)
#
# Run: 296, exploration: 0.1, score: 55
# Scores: (min: 8, avg: 14.3, max: 113)
#
# Run: 297, exploration: 0.1, score: 42
# Scores: (min: 8, avg: 14.61, max: 113)
#
# Run: 298, exploration: 0.1, score: 107
# Scores: (min: 8, avg: 15.6, max: 113)
#
# Run: 299, exploration: 0.1, score: 64
# Scores: (min: 8, avg: 16.13, max: 113)
#
# Run: 300, exploration: 0.1, score: 111
# Scores: (min: 8, avg: 17.13, max: 113)
#
# Run: 301, exploration: 0.1, score: 79
# Scores: (min: 8, avg: 17.83, max: 113)
#
# Run: 302, exploration: 0.1, score: 131
# Scores: (min: 8, avg: 19.01, max: 131)
#
# Run: 303, exploration: 0.1, score: 110
# Scores: (min: 8, avg: 20.01, max: 131)
#
# Run: 304, exploration: 0.1, score: 58
# Scores: (min: 8, avg: 20.48, max: 131)
#
# Run: 305, exploration: 0.1, score: 155
# Scores: (min: 8, avg: 21.93, max: 155)
#
# Run: 306, exploration: 0.1, score: 69
# Scores: (min: 8, avg: 22.53, max: 155)
#
# Run: 307, exploration: 0.1, score: 78
# Scores: (min: 8, avg: 23.21, max: 155)
#
# Run: 308, exploration: 0.1, score: 97
# Scores: (min: 8, avg: 24.08, max: 155)
# Run: 309, exploration: 0.1, score: 113
# Scores: (min: 8, avg: 25.1, max: 155)
#
# Run: 310, exploration: 0.1, score: 124
# Scores: (min: 8, avg: 26.25, max: 155)
#
# Run: 311, exploration: 0.1, score: 125
# Scores: (min: 8, avg: 27.42, max: 155)
#
# Run: 312, exploration: 0.1, score: 106
# Scores: (min: 8, avg: 28.38, max: 155)
#
# Run: 313, exploration: 0.1, score: 123
# Scores: (min: 8, avg: 29.52, max: 155)
#
# Run: 314, exploration: 0.1, score: 113
# Scores: (min: 8, avg: 30.55, max: 155)
#
# Run: 315, exploration: 0.1, score: 109
# Scores: (min: 8, avg: 31.54, max: 155)
#
# Run: 316, exploration: 0.1, score: 108
# Scores: (min: 8, avg: 32.5, max: 155)
#
# Run: 317, exploration: 0.1, score: 93
# Scores: (min: 8, avg: 33.34, max: 155)
#
# Run: 318, exploration: 0.1, score: 36
# Scores: (min: 8, avg: 33.61, max: 155)
#
# Run: 319, exploration: 0.1, score: 88
# Scores: (min: 8, avg: 34.4, max: 155)
#
# Run: 320, exploration: 0.1, score: 95
# Scores: (min: 8, avg: 35.26, max: 155)
#
# Run: 321, exploration: 0.1, score: 104
# Scores: (min: 8, avg: 36.2, max: 155)
#
# Run: 322, exploration: 0.1, score: 35
# Scores: (min: 8, avg: 36.46, max: 155)
#
# Run: 323, exploration: 0.1, score: 33
# Scores: (min: 8, avg: 36.71, max: 155)
#
# Run: 324, exploration: 0.1, score: 42
# Scores: (min: 8, avg: 37.03, max: 155)
#
# Run: 325, exploration: 0.1, score: 103
# Scores: (min: 8, avg: 37.96, max: 155)
#
# Run: 326, exploration: 0.1, score: 27
# Scores: (min: 8, avg: 38.15, max: 155)
#
# Run: 327, exploration: 0.1, score: 31
# Scores: (min: 8, avg: 38.38, max: 155)
#
# Run: 328, exploration: 0.1, score: 28
# Scores: (min: 8, avg: 38.56, max: 155)
#
# Run: 329, exploration: 0.1, score: 32
# Scores: (min: 8, avg: 38.79, max: 155)
#
# Run: 330, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 39, max: 155)
#
# Run: 331, exploration: 0.1, score: 26
# Scores: (min: 8, avg: 39.17, max: 155)
#
# Run: 332, exploration: 0.1, score: 31
# Scores: (min: 8, avg: 39.38, max: 155)
#
# Run: 333, exploration: 0.1, score: 39
# Scores: (min: 8, avg: 39.67, max: 155)
#
# Run: 334, exploration: 0.1, score: 97
# Scores: (min: 8, avg: 40.52, max: 155)
#
# Run: 335, exploration: 0.1, score: 34
# Scores: (min: 8, avg: 40.77, max: 155)
#
# Run: 336, exploration: 0.1, score: 93
# Scores: (min: 8, avg: 41.59, max: 155)
#
# Run: 337, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 46.47, max: 500)
#
# Run: 338, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 51.37, max: 500)
#
# Run: 339, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 56.27, max: 500)
#
# Run: 340, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 61.18, max: 500)
#
# Run: 341, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 66.08, max: 500)
#
# Run: 342, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 70.97, max: 500)
#
# Run: 343, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 75.88, max: 500)
#
# Run: 344, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 80.79, max: 500)
#
# Run: 345, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 85.7, max: 500)
#
# Run: 346, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 90.6, max: 500)
#
# Run: 347, exploration: 0.1, score: 386
# Scores: (min: 8, avg: 94.37, max: 500)
#
# Run: 348, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 99.29, max: 500)
#
# Run: 349, exploration: 0.1, score: 371
# Scores: (min: 8, avg: 102.89, max: 500)
#
# Run: 350, exploration: 0.1, score: 238
# Scores: (min: 8, avg: 105.17, max: 500)
#
# Run: 351, exploration: 0.1, score: 301
# Scores: (min: 8, avg: 108.08, max: 500)
#
# Run: 352, exploration: 0.1, score: 461
# Scores: (min: 8, avg: 112.6, max: 500)
#
# Run: 353, exploration: 0.1, score: 249
# Scores: (min: 8, avg: 115, max: 500)
#
# Run: 354, exploration: 0.1, score: 339
# Scores: (min: 8, avg: 118.27, max: 500)
#
# Run: 355, exploration: 0.1, score: 263
# Scores: (min: 8, avg: 120.82, max: 500)
#
# Run: 356, exploration: 0.1, score: 233
# Scores: (min: 8, avg: 123.04, max: 500)
#
# Run: 357, exploration: 0.1, score: 156
# Scores: (min: 8, avg: 124.51, max: 500)
#
# Run: 358, exploration: 0.1, score: 233
# Scores: (min: 8, avg: 126.74, max: 500)
#
# Run: 359, exploration: 0.1, score: 264
# Scores: (min: 8, avg: 129.27, max: 500)
#
# Run: 360, exploration: 0.1, score: 176
# Scores: (min: 8, avg: 130.94, max: 500)
#
# Run: 361, exploration: 0.1, score: 279
# Scores: (min: 8, avg: 133.64, max: 500)
#
# Run: 362, exploration: 0.1, score: 271
# Scores: (min: 8, avg: 136.26, max: 500)
#
# Run: 363, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 141.16, max: 500)
#
# Run: 364, exploration: 0.1, score: 337
# Scores: (min: 8, avg: 144.43, max: 500)
#
# Run: 365, exploration: 0.1, score: 196
# Scores: (min: 8, avg: 146.28, max: 500)
#
# Run: 366, exploration: 0.1, score: 313
# Scores: (min: 8, avg: 149.3, max: 500)
#
# Run: 367, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 154.2, max: 500)
#
# Run: 368, exploration: 0.1, score: 349
# Scores: (min: 8, avg: 157.59, max: 500)
#
# Run: 369, exploration: 0.1, score: 153
# Scores: (min: 8, avg: 159.03, max: 500)
#
# Run: 370, exploration: 0.1, score: 208
# Scores: (min: 9, avg: 161.03, max: 500)
#
# Run: 371, exploration: 0.1, score: 250
# Scores: (min: 9, avg: 163.43, max: 500)
#
# Run: 372, exploration: 0.1, score: 275
# Scores: (min: 9, avg: 166.06, max: 500)
#
# Run: 373, exploration: 0.1, score: 226
# Scores: (min: 9, avg: 168.2, max: 500)
#
# Run: 374, exploration: 0.1, score: 209
# Scores: (min: 9, avg: 170.19, max: 500)
#
# Run: 375, exploration: 0.1, score: 359
# Scores: (min: 9, avg: 173.69, max: 500)
#
# Run: 376, exploration: 0.1, score: 289
# Scores: (min: 9, avg: 176.47, max: 500)
#
# Run: 377, exploration: 0.1, score: 322
# Scores: (min: 9, avg: 179.58, max: 500)
#
# Run: 378, exploration: 0.1, score: 266
# Scores: (min: 9, avg: 182.15, max: 500)
#
# Run: 379, exploration: 0.1, score: 392
# Scores: (min: 9, avg: 185.97, max: 500)
#
# Run: 380, exploration: 0.1, score: 186
# Scores: (min: 9, avg: 187.73, max: 500)
#
# Run: 381, exploration: 0.1, score: 287
# Scores: (min: 11, avg: 190.51, max: 500)
#
# Run: 382, exploration: 0.1, score: 132
# Scores: (min: 11, avg: 191.72, max: 500)
#
# Run: 383, exploration: 0.1, score: 297
# Scores: (min: 11, avg: 194.58, max: 500)
#
# Run: 384, exploration: 0.1, score: 236
# Scores: (min: 22, avg: 196.83, max: 500)
#
# Solved in 284 runs, 384 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-dfb60c9f6d93> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# In the cartpole problem the goal is to balance a pole on a moving cart by pushing it left or right. The model uses four pieces of information to decide what to do: the cart's position, the cart's speed, the pole's angle, and the pole's rotation speed. The model can perform two actions, push the cart to the left or right. The model learns how to balance the pole using a method called Deep Q-Learning, which involves using a neural network to predict the best action based on its past experiences stored in memory. These experiences are randomly sampled during training which helps the model learn more effectively by utilizing a set of diverse training examples.
#
# The neural network in the DQN has an input layer for the state values, two hidden layers to process the information, and an output layer that suggests the best action for the model to take. Adjusting the learning rate can impact the training process. A high learning rate can make learning faster but unstable, while a low learning rate results in slower but steadier learning. The neural network helps make the Q-learning algorithm more efficient by generalizing from past experiences to new states it can't see, improving the model's ability to learn the task of balancing the pole on the cart.
